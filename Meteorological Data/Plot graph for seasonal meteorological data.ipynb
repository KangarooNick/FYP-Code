# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Temperature and Energy Generation

# %%
data1 = pd.read_excel('Temperature Monthly.xlsx')

# %%
print(data1)
# Out:
#         Month  Geometric mean  Arithmetic mean
# 0  2022-09-01       28.711304        28.869506
# 1  2022-10-01       25.015129        25.260606
# 2  2022-11-01       21.869291        21.978796
# 3  2022-12-01       14.999524        15.406449
# 4  2023-01-01       15.292077        15.695140
# 5  2023-02-01       17.119975        17.347007
# 6  2023-03-01       19.321642        19.487173
# 7  2023-04-01       21.905280        22.057447
# 8  2023-05-01       24.876190        25.074226
# 9  2023-06-01       27.851179        27.936161
# 10 2023-07-01       29.075165        29.196735
# 11 2023-08-01       28.838703        28.946757

# %%
data1.plot(x='Month', y='Arithmetic mean', kind='line')
plt.ylim(0, 30)
plt.xlabel('Month')
plt.ylabel('Average temperature')
#add points on the data
plt.show()

# %%
data2 = pd.read_excel('Monthly Mean Energy Generation.xlsx')

# %%
print(data2)
# Out:
#         Month       Mean
# 0  2022-09-01  3345.3922
# 1  2022-10-01  3183.2600
# 2  2022-11-01  1520.1900
# 3  2022-12-01  2376.5100
# 4  2023-01-01  2428.4300
# 5  2023-02-01  2722.9100
# 6  2023-03-01  2846.9600
# 7  2023-04-01  2245.7200
# 8  2023-05-01  3103.3300
# 9  2023-06-01  3221.8200
# 10 2023-07-01  4574.6400
# 11 2023-08-01  4111.3100

# %%
data2.plot(x='Month', y='Mean', kind='line')
plt.xlabel('Month')
plt.ylabel('Average Energy generation')
plt.show()

# %%
# Create the figure and the first y-axis
fig, ax1 = plt.subplots()

# Plot the first dataset on the first y-axis
ax1.plot(data1['Month'], data1['Arithmetic mean'], color='blue')
ax1.set_xlabel('Month')
ax1.set_ylabel('Average Temperature (Degree Celsius)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Add the blue dots on the line
ax1.scatter(data1['Month'], data1['Arithmetic mean'], color='blue')

# Create the second y-axis
ax2 = ax1.twinx()

# Plot the second dataset on the second y-axis
ax2.plot(data2['Month'], data2['Mean'], color='red')
ax2.set_ylabel('Average Energy Generation (kWh)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Customize the graph
plt.title('Relationship between Temperature and Energy Generation')
plt.legend()

#add the points on the data
ax1.scatter(data1['Month'], data1['Arithmetic mean'], color='blue')
plt.scatter(data2['Month'], data2['Mean'], color='red')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Calculate the correlation coefficient
correlation = data1['Arithmetic mean'].corr(data2['Mean'])

print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.7052138756948699

# %% [markdown]
# Relative Humidity and Energy Generation

# %%
data3 = pd.read_excel('RH monthly.xlsx')
print(data3)
# Out:
#         Month  Geometric mean  Arithmetic Mean
# 0  2022-09-01       66.982156        69.177511
# 1  2022-10-01       63.221772        65.717839
# 2  2022-11-01       87.091084        87.811510
# 3  2022-12-01       59.404183        63.074673
# 4  2023-01-01       64.839156        68.797943
# 5  2023-02-01       74.766543        76.781676
# 6  2023-03-01       78.504847        80.947357
# 7  2023-04-01       87.701781        88.931329
# 8  2023-05-01       85.037001        86.137244
# 9  2023-06-01       85.928977        86.440516
# 10 2023-07-01       78.847946        79.897492
# 11 2023-08-01       79.769868        80.606336

# %%
data3.plot(x='Month', y='Arithmetic Mean', kind='line')
plt.ylim(30,100)
plt.xlabel('Month')
plt.ylabel('Average Relative Humidity')
plt.show()

# %%
# Create the figure and the first y-axis
fig, ax1 = plt.subplots()

# Plot the first dataset on the first y-axis
ax1.plot(data3['Month'], data3['Arithmetic Mean'], color='blue')
ax1.set_xlabel('Month')
ax1.set_ylabel('Average Relative Humidity(%)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create the second y-axis
ax2 = ax1.twinx()

# Plot the second dataset on the second y-axis
ax2.plot(data2['Month'], data2['Mean'], color='red')
ax2.set_ylabel('Average Energy Generation(kWh)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

#add the points on the data
ax1.scatter(data3['Month'], data3['Arithmetic Mean'], color='blue')
plt.scatter(data2['Month'], data2['Mean'], color='red')

# Customize the graph
plt.title('Relationship between Relative Humidity and Energy Generation')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Calculate the correlation coefficient
correlation = data3['Arithmetic Mean'].corr(data2['Mean'])

print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: -0.0612617986051446

# %% [markdown]
# Solar Irradiance and Energy Generation

# %%
data4 = pd.read_excel('Daily Solar irradiance.xlsx')
print(data4)
# Out:
#           Time        W/m2
# 0   2022-09-01  5099.64720
# 1   2022-09-02  4615.37450
# 2   2022-09-03  5790.94690
# 3   2022-09-04  5886.04805
# 4   2022-09-05  5155.25000
# ..         ...         ...
# 360 2023-08-27  4351.98340
# 361 2023-08-28  5484.53950
# 362 2023-08-29  6800.14580
# 363 2023-08-30  8959.82830
# 364 2023-08-31  5581.19390
#
# [365 rows x 2 columns]

# %%
monthly_mean = data4.groupby(data4['Time'].dt.month)['W/m2'].mean()
monthly_mean
# Out:
# Time
# 1     2686.150106
# 2     4451.445546
# 3     4506.624593
# 4     4131.780017
# 5     5366.491865
# 6     6165.308757
# 7     7240.718329
# 8     6636.758313
# 9     4476.975709
# 10    4236.209964
# 11    2296.208137
# 12    2893.704659
# Name: W/m2, dtype: float64

# %%
monthly_mean.to_excel('Monthly Irradiance.xlsx')

# %%
data4 = pd.read_excel('Monthly Irradiance.xlsx')
print(data4)
# Out:
#          Time         W/m2
# 0  2022-09-01  4476.975709
# 1  2022-10-01  4236.209964
# 2  2022-11-01  2296.208137
# 3  2022-12-01  2893.704659
# 4  2023-01-01  2686.150106
# 5  2023-02-01  4451.445546
# 6  2023-03-01  4506.624593
# 7  2023-04-01  4131.780017
# 8  2023-05-01  5366.491865
# 9  2023-06-01  6165.308757
# 10 2023-07-01  7240.718329
# 11 2023-08-01  6636.758313

# %%
# Create the figure and the first y-axis
fig, ax1 = plt.subplots()

# Plot the first dataset on the first y-axis
ax1.plot(data4['Time'], data4['W/m2'], color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Average Solar Irradiance(W/m2)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create the second y-axis
ax2 = ax1.twinx()

# Plot the second dataset on the second y-axis
ax2.plot(data2['Month'], data2['Mean'], color='red')
ax2.set_ylabel('Average Energy Generation(kWh)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

#add the points on the data
ax1.scatter(data4['Time'], data4['W/m2'], color='blue')
plt.scatter(data2['Month'], data2['Mean'], color='red')

# Customize the graph
plt.title('Relationship between Solar Irradiance and Energy Generation')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Calculate the correlation coefficient
correlation = data4['W/m2'].corr(data2['Mean'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.9031344718840697
