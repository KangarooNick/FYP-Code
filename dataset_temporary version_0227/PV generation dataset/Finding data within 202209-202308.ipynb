# %%
import os
import pandas as pd

# Specify the folder path using a raw string literal
folder_path = r'C:\Users\nickc\OneDrive - HKUST Connect\桌面\FYP Code\dataset_temporary version_0227\PV generation dataset\PV stations with panel level optimizer\Site level dataset'

# Get all the CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Read and display the data from each excel file
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    print(f"Data from {file}:")
    print(df)
    print()
#Only choose data between 2022-09-01 to 2023-08-31
    start_date = '2022-09-01 00:00'
    end_date = '2023-08-31 23:59'

    filtered_df = df.loc[df['Time'].between(start_date, end_date)]
    filtered_df

    #Only include data from 7am to 7pm of each day
    filtered_df['Time'] = pd.to_datetime(filtered_df['Time'])
    filtered_df = filtered_df.set_index('Time')
    filtered_df = filtered_df.between_time('07:00', '19:00')
    filtered_df = filtered_df.reset_index()
    filtered_df

    #Export and name the excel files base on the original file name
    filtered_df.to_csv(file, index = False)
# Out:
# Data from Indoor Sports Centre.csv:
#                       Time  generation(kWh)  power(W)
# 0      2021-12-02 00:00:00              0.0       0.0
# 1      2021-12-02 00:15:00              0.0       0.0
# 2      2021-12-02 00:30:00              0.0       0.0
# 3      2021-12-02 00:45:00              0.0       0.0
# 4      2021-12-02 01:00:00              0.0       0.0
# ...                    ...              ...       ...
# 72955  2023-12-31 22:45:00              0.0       0.0
# 72956  2023-12-31 23:00:00              0.0       0.0
# 72957  2023-12-31 23:15:00              0.0       0.0
# 72958  2023-12-31 23:30:00              0.0       0.0
# 72959  2023-12-31 23:45:00              0.0       0.0
#
# [72960 rows x 3 columns]
#
# Data from Library.csv:
#                       Time  generation(kWh)  power(W)
# 0      2022-06-01 00:00:00              0.0       0.0
# 1      2022-06-01 00:15:00              0.0       0.0
# 2      2022-06-01 00:30:00              0.0       0.0
# ...

# %%
df = df.assign(NewColumn='SameData')
df = df.assign(NewColumn='YourValue')
