# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy
import datetime as dt
df = pd.read_excel('All Efficiency @7am-7pm.xlsx')

# %%
df
# Out:
#                      Time  Indoor Sports Centre    Library  LSK North  \
# 0     2022-09-01 07:00:00             13.243705  13.672668  13.974872
# 1     2022-09-01 07:15:00             14.941745  15.444832  15.255759
# 2     2022-09-01 07:30:00             15.967707  16.172525  15.940151
# 3     2022-09-01 07:45:00             16.969085  16.939192  17.451269
# 4     2022-09-01 08:00:00             17.711631  17.232686  18.508536
# ...                   ...                   ...        ...        ...
# 17880 2023-08-31 18:00:00              3.624177   3.144747   2.845053
# 17881 2023-08-31 18:15:00              1.771081   1.359712   0.863333
# 17882 2023-08-31 18:30:00              0.000000   0.431660   0.549316
# 17883 2023-08-31 18:45:00              0.000000   0.000000   0.000000
# 17884 2023-08-31 19:00:00              0.000000   0.000000   0.000000
#
#        LSK South  S H Ho Sports Hall  Shaw Auditorium  SQ Apartment1-12  \
# ...

# %% [markdown]
# Average Efficiency per day

# %%
df['Time'] = pd.to_datetime(df['Time'])
df.set_index('Time', inplace=True)
daily_df = df.resample('D').mean()
daily_df
# Out:
#             Indoor Sports Centre    Library  LSK North  LSK South  \
# Time
# 2022-09-01             17.877141  15.567035  16.381227  17.342682
# 2022-09-02             18.564764  15.951502  18.353910  19.988993
# 2022-09-03             17.834132  16.063525  17.805694  19.624351
# 2022-09-04             17.661456  15.784070  18.087689  20.169962
# 2022-09-05             16.235174  15.051677  17.280642  19.180132
# ...                          ...        ...        ...        ...
# 2023-08-27             10.650584  10.072161   9.677138  10.309618
# 2023-08-28             11.377784  10.113265  10.222456  10.981545
# 2023-08-29             11.048148  10.125169  10.000654  10.699400
# 2023-08-30             10.931311  10.333550  10.466624  11.071208
# 2023-08-31              9.905346   9.311236   9.760997   9.164604
#
#             S H Ho Sports Hall  Shaw Auditorium  SQ Apartment1-12  \
# Time
# 2022-09-01           13.473256              NaN         15.345565
# ...

# %% [markdown]
# Data Clear

# %%
#Remove all data with values >40, while the name of each column is the name of the location
for column in daily_df:
    cleaned_df = daily_df[daily_df[column] < 40]
    cleaned_df = daily_df[daily_df[column] >= 0]
cleaned_df
# Out:
#             Indoor Sports Centre    Library  LSK North  LSK South  \
# Time
# 2022-09-01             17.877141  15.567035  16.381227  17.342682
# 2022-09-02             18.564764  15.951502  18.353910  19.988993
# 2022-09-03             17.834132  16.063525  17.805694  19.624351
# 2022-09-04             17.661456  15.784070  18.087689  20.169962
# 2022-09-05             16.235174  15.051677  17.280642  19.180132
# ...                          ...        ...        ...        ...
# 2023-08-27             10.650584  10.072161   9.677138  10.309618
# 2023-08-28             11.377784  10.113265  10.222456  10.981545
# 2023-08-29             11.048148  10.125169  10.000654  10.699400
# 2023-08-30             10.931311  10.333550  10.466624  11.071208
# 2023-08-31              9.905346   9.311236   9.760997   9.164604
#
#             S H Ho Sports Hall  Shaw Auditorium  SQ Apartment1-12  \
# Time
# 2022-09-01           13.473256              NaN         15.345565
# ...

# %% [markdown]
# Average Monthly Efficiency of all location

# %%
#Find the monthly average data
monthly_df = cleaned_df.resample('M').mean()
monthly_df
# Out:
#             Indoor Sports Centre    Library  LSK North  LSK South  \
# Time
# 2022-09-30              6.215583  14.337686  16.066719  17.385604
# 2022-10-31              4.248406  12.977963  15.773309  17.698408
# 2022-11-30              6.729447   9.061978  13.390470  15.011157
# 2022-12-31              6.529708  13.211344  16.351494  19.337212
# 2023-01-31              7.168691  13.832477  15.603588  17.299503
# 2023-02-28             11.877788  15.596228  17.248083  18.465225
# 2023-03-31             10.521123   9.564309   9.846225  10.123268
# 2023-04-30              9.566337   8.779171   8.662564   8.949034
# 2023-05-31             10.711501  10.093344   9.858307  10.138735
# 2023-06-30             11.023375  10.490704  10.180711  10.712256
# 2023-07-31             12.118988  12.216261  11.426607  12.338409
# 2023-08-31             10.951885  10.662707  10.401426  11.155075
#
#             S H Ho Sports Hall  Shaw Auditorium  SQ Apartment1-12  \
# Time
# ...

# %%
#Plot the monthly average data of all locations
monthly_df.plot()
plt.title('Monthly Average Data')
plt.xlabel('Time')
plt.ylabel('Average Efficiency')
#Hide the mention of the location
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#add a scatter plot for the line showing the average value of the data
plt.scatter(monthly_df.index, monthly_df.mean(axis=1), color='black')
#remove the data of "all locations"
plt.show()

# %%
#Combine them into one line and plot the monthly average data of all locations
monthly_df['All Locations'] = monthly_df.mean(axis=1)
monthly_df['All Locations'].plot()
plt.title('Monthly Average Data of All Locations')
plt.xlabel('Time')
plt.ylabel('Average Efficiency')
#adjust the lower and upper bound
plt.ylim(0, 20)
#add a scatter plot for the line showing the average value of the data
plt.scatter(monthly_df.index, monthly_df['All Locations'], color='black')
plt.show()

# %% [markdown]
# Hourly data

# %%
df
# Out:
#                      Indoor Sports Centre    Library  LSK North  LSK South  \
# Time
# 2022-09-01 07:00:00             13.243705  13.672668  13.974872  16.573307
# 2022-09-01 07:15:00             14.941745  15.444832  15.255759  18.177544
# 2022-09-01 07:30:00             15.967707  16.172525  15.940151  18.929523
# 2022-09-01 07:45:00             16.969085  16.939192  17.451269  19.557656
# 2022-09-01 08:00:00             17.711631  17.232686  18.508536  20.002786
# ...                                   ...        ...        ...        ...
# 2023-08-31 18:00:00              3.624177   3.144747   2.845053   0.000000
# 2023-08-31 18:15:00              1.771081   1.359712   0.863333   0.000000
# 2023-08-31 18:30:00              0.000000   0.431660   0.549316   0.000000
# 2023-08-31 18:45:00              0.000000   0.000000   0.000000   0.000000
# 2023-08-31 19:00:00              0.000000   0.000000   0.000000   0.000000
#
# ...

# %%
hourly_df = df.resample('H').mean()
hourly_df
#I want the average hourly data from 7am to 7pm, don't have to care about the date
hourly_df = hourly_df.between_time('07:00:00', '19:00:00')
#Plot a graph with x axis is time period from 7am to 7pm, y axis is the average efficiency
hourly_df.plot()
plt.title('Average Efficiency from 7am to 7pm')
plt.xlabel('Time')
plt.ylabel('Average Efficiency')
#adjust the legend
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# Location data

# %%
# I want to know the average efficiency of each location at each hour
hourly_df.mean()
hourly_df.mean().plot(kind='bar')
plt.title('Average Efficiency of Each Location')
plt.xlabel('Location')
plt.ylabel('Average Efficiency')
plt.show()

# %% [markdown]
# Hourly variation

# %%
# I want the average efficiency of all locations of the whole year at 8am
hourly_df['All Locations'] = hourly_df.mean(axis=1)
hourly_df
# Out:
#                      Indoor Sports Centre    Library  LSK North  LSK South  \
# Time
# 2022-09-01 07:00:00             15.280561  15.557305  15.655513  18.309508
# 2022-09-01 08:00:00             18.474705  17.706808  18.847293  20.223448
# 2022-09-01 09:00:00             20.147635  17.489169  19.107396  19.416154
# 2022-09-01 10:00:00             21.125649  17.572660  19.070948  19.560959
# 2022-09-01 11:00:00             21.468724  18.569622  19.551199  20.275708
# ...                                   ...        ...        ...        ...
# 2023-08-31 15:00:00             12.041645  11.259283  11.600483        NaN
# 2023-08-31 16:00:00             10.964767  10.236701   9.993096        NaN
# 2023-08-31 17:00:00              5.598800   4.885380   4.803749        NaN
# 2023-08-31 18:00:00              1.348814   1.234030   1.064426   0.000000
# 2023-08-31 19:00:00              0.000000   0.000000   0.000000   0.000000
#
# ...

# %%
#I want all 07:00:00 data
hourly9_df = hourly_df.between_time('19:00:00', '19:00:00')
hourly9_df
#Find the mean value of them
#hourly8_df.mean()
#Take the average of them, not plot graph
print(hourly9_df.mean())
# Out:
# Indoor Sports Centre              0.015629
# Library                           0.063973
# LSK North                         0.032339
# LSK South                         0.001637
# S H Ho Sports Hall                0.002264
# Shaw Auditorium                   0.000000
# SQ Apartment1-12                  0.000000
# SQ Apartment13-24                 0.007336
# SQ Apartment25-36                 0.003704
# SQ Block P                        0.000000
# SQ Block R                        0.000032
# SQ Block S                        0.000000
# SQ1                               0.000630
# SQ2                               0.000108
# SQ3                               0.000000
# SQ4                               0.000000
# UG Hall2 2F                       0.013776
# UG Hall2 RF                       0.000000
# UG Hall3                          0.048981
# UG Hall6                          0.023972
# UG Hall8                          0.018111
# UG Hall9                          0.000722
# ...

# %%
within_df =pd.read_excel('Within day.xlsx')
within_df
#remove index
#within_df = within_df.set_index('Time')
within_df
# Out:
#         Time  Efficiency
# 0   07:00:00    7.896100
# 1   08:00:00   11.677157
# 2   09:00:00   13.156613
# 3   10:00:00   13.774378
# 4   11:00:00   14.159117
# 5   12:00:00   13.517057
# 6   13:00:00   13.467888
# 7   14:00:00   13.312962
# 8   15:00:00   12.726078
# 9   16:00:00   12.918821
# 10  17:00:00    8.308230
# 11  18:00:00    1.548032
# 12  19:00:00    0.017519

# %%
#plot a graph
import numpy as np
import timedelta as td
within_df.plot()    
plt.title('Efficiency within a day')
plt.xlabel('Time')
plt.ylabel('Efficiency')
#the x axis could be in the format of time
#plt.xticks(np.arange(0, 13 , step=1))
# adjust the ticks: 0 be 07:00:00, 1 be 08:00:00, 2 be 09:00:00, etc
plt.xticks(np.arange(0, 13, step=1), ['7am', '8am', '9am', '10am', '11am', '12pm', '1pm', '2pm', '3pm', '4pm', '5pm', '6pm', '7pm'])
#adjust the size of the graph
plt.ylim(0, 20)
plt.show()

# %%
irradiance_data = pd.read_excel(r'C:\Users\nickc\OneDrive - HKUST Connect\桌面\FYP Code\dataset_temporary version_0227\Meteorological dataset\required irradiance-M15.xlsx')
irradiance_data
# Out:
#                      Time  Irradiance (W/m2)
# 0     2022-09-01 00:00:00          18.619133
# 1     2022-09-01 00:15:00          19.185267
# 2     2022-09-01 00:30:00          19.824400
# 3     2022-09-01 00:45:00          20.102933
# 4     2022-09-01 01:00:00          20.197867
# ...                   ...                ...
# 35035 2023-08-31 22:45:00          35.965400
# 35036 2023-08-31 23:00:00          36.038467
# 35037 2023-08-31 23:15:00          36.275000
# 35038 2023-08-31 23:30:00          36.937067
# 35039 2023-08-31 23:45:00          37.657533
#
# [35040 rows x 2 columns]

# %%
df
import numpy as np
import timedelta as td
import datetime as dt
# I want to know the average efficiency of all location at each 15 minutes
quarterly_df = df.resample('15T').mean()
#take the mean of all locations at each 15 minutes
quarterly_df['All Locations'] = df.mean(axis=1)
quarterly_df
#print all values
print(quarterly_df['All Locations'])
location_mean_df = quarterly_df['All Locations']
print(location_mean_df)
# Out:
# Time
# 2022-09-01 07:00:00    11.015535
# 2022-09-01 07:15:00    12.390065
# 2022-09-01 07:30:00    13.179211
# 2022-09-01 07:45:00    14.026034
# 2022-09-01 08:00:00    14.662814
#                          ...
# 2023-08-31 18:00:00     2.561098
# 2023-08-31 18:15:00     0.912104
# 2023-08-31 18:30:00     0.137019
# 2023-08-31 18:45:00     0.000000
# 2023-08-31 19:00:00     0.000000
# Freq: 15T, Name: All Locations, Length: 34993, dtype: float64
# Time
# 2022-09-01 07:00:00    11.015535
# 2022-09-01 07:15:00    12.390065
# 2022-09-01 07:30:00    13.179211
# 2022-09-01 07:45:00    14.026034
# 2022-09-01 08:00:00    14.662814
#                          ...
# 2023-08-31 18:00:00     2.561098
# 2023-08-31 18:15:00     0.912104
# 2023-08-31 18:30:00     0.137019
# 2023-08-31 18:45:00     0.000000
# 2023-08-31 19:00:00     0.000000
# Freq: 15T, Name: All Locations, Length: 34993, dtype: float64

# %%
location_mean_df
#convert it to a dataframe
location_mean_df = location_mean_df.to_frame()
location_mean_df
# Out:
#                      All Locations
# Time
# 2022-09-01 07:00:00      11.015535
# 2022-09-01 07:15:00      12.390065
# 2022-09-01 07:30:00      13.179211
# 2022-09-01 07:45:00      14.026034
# 2022-09-01 08:00:00      14.662814
# ...                            ...
# 2023-08-31 18:00:00       2.561098
# 2023-08-31 18:15:00       0.912104
# 2023-08-31 18:30:00       0.137019
# 2023-08-31 18:45:00       0.000000
# 2023-08-31 19:00:00       0.000000
#
# [34993 rows x 1 columns]

# %%
location_mean_df

quarter_df = pd.DataFrame()
for i in range(7, 20):
    time = dt.time(i, 0)
    for j in range(0, 59, 15):
        time = dt.time(i, j)   
        quarterly_df = location_mean_df.between_time(time, time)
        interval_df = quarterly_df.mean()
        print(interval_df)

        quarter_df = pd.concat([quarter_df, interval_df]) 
quarter_df
# Out:
# All Locations    5.846637
# dtype: float64
# All Locations    7.42076
# dtype: float64
# All Locations    8.611986
# dtype: float64
# All Locations    9.679471
# dtype: float64
# All Locations    10.562985
# dtype: float64
# All Locations    11.450532
# dtype: float64
# All Locations    12.18275
# dtype: float64
# All Locations    12.51121
# dtype: float64
# All Locations    12.763952
# dtype: float64
# All Locations    13.039757
# dtype: float64
# All Locations    13.375812
# dtype: float64
# All Locations    13.450128
# dtype: float64
# All Locations    13.752611
# dtype: float64
# All Locations    13.751364
# dtype: float64
# All Locations    14.000579
# dtype: float64
# All Locations    13.590451
# dtype: float64
# All Locations    13.765235
# dtype: float64
# All Locations    14.279709
# dtype: float64
# All Locations    14.523006
# dtype: float64
# All Locations    14.07255
# dtype: float64
# All Locations    13.689818
# dtype: float64
# All Locations    13.615358
# ...

# %%
#change the index of the dataframe to be the time
quarter_df.index = pd.date_range(start='07:00:00', periods=52, freq='15T')
quarter_df
#remove the date
quarter_df.index = quarter_df.index.time
quarter_df
quarter_df.to_excel('quarter_df.xlsx')
